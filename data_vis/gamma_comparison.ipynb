w7_oc_gn = [0.05736243341807556,
 0.05231309955981067,
 0.04545037564142192,
 0.03843275248108525,
 0.03157499047935487,
 0.024089330816535796,
 0.01758646814689742,
 0.012274438603472668,
 0.009724518238234248]

w10_oc_gn = [0.05736243341807556,
 0.05281315734040981,
 0.04552272228755573,
 0.0392726714942721,
 0.03187937275456453,
 0.024856355143754793,
 0.016718442354518255,
 0.010917432377181612,
 0.01218065737471282]
w10_oc_gp = [0.15419688673118392,
 0.14839773763637457,
 0.1304347661908953,
 0.11715646584475174,
 0.10133345697625099,
 0.08712078936311549,
 0.07026708017083888,
 0.056339985368165216,
 0.05763895195979437]
w10_oc_hr =[0.5387062566277837,
 0.5418875927889714,
 0.5355249204665959,
 0.5312831389183457,
 0.5302226935312832,
 0.5302226935312832,
 0.5344644750795334,
 0.5206786850477201,
 0.5100742311770944]
w10_oc_ndcg = [0.06877010356676778,
 0.0681084096950953,
 0.06769448961303162,
 0.06754479275730804,
 0.06761844737433326,
 0.06827837445154866,
 0.06854839403057277,
 0.06172142057269882,
 0.05766886343172385]

# %%
x = list(range(0,9))
data_pairs=[(w1_oc_gp, w3_oc_gp, w5_oc_gp,w7_oc_gp,w10_oc_gp),(w1_oc_gn, w3_oc_gn, w5_oc_gn, w7_oc_gn, w10_oc_gn),(w1_oc_hr, w3_oc_hr, w5_oc_hr, w7_oc_hr, w10_oc_hr),(w1_oc_ndcg, w3_oc_ndcg, w5_oc_ndcg, w7_oc_ndcg, w10_oc_ndcg)]
labels =  ["w1", "w1", "w1", "w1"]
labels2 =  ["w3", "w3", "w3", "w3"]
labels3 =  ["w5", "w5", "w5", "w5"]
labels4 =  ["w7", "w7", "w7", "w7"]
labels5 =  ["w10", "w10", "w10", "w10"]
plotTitles = ["CC bias 1","CDCG bias 2","HR performance 1","NDCG performance 2"]
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()
for i, (ax, (y_left, y_right, y_another, y_7, y_10)) in enumerate(zip(axes, data_pairs)):
    print(i)
    ax.plot(x, y_left, 'b-o', label=f"{labels[i]}")
    ax.tick_params(axis='y', labelcolor='b')

    ax.plot(x, y_right, 'r-s',label=f"{labels2[i]}")
    ax.tick_params(axis='y', labelcolor='r')
    
    ax.plot(x, y_another, 'g-s', label=f"{labels3[i]}")
    ax.tick_params(axis='y', labelcolor='g')
    
    ax.plot(x, y_7, 'c-s', label=f"{labels4[i]}")
    ax.tick_params(axis='y', labelcolor='c')
    ax.plot(x, y_10, 'm-s', label=f"{labels5[i]}")
    ax.tick_params(axis='y', labelcolor='m')

    ax.set_xlabel("X-axis Label")
    ax.set_title(f"{plotTitles[i]}")
    ax.legend(loc="upper left")
    

plt.tight_layout()
plt.show()
# Out:
# 0
# 1
# 2
# 3

# %%
import numpy as np

# Sample data
x = list(range(0, 9))
data_pairs = [
    (w1_oc_gp, w3_oc_gp, w5_oc_gp, w7_oc_gp, w10_oc_gp),
    (w1_oc_gn, w3_oc_gn, w5_oc_gn, w7_oc_gn, w10_oc_gn),
    (w1_oc_hr, w3_oc_hr, w5_oc_hr, w7_oc_hr, w10_oc_hr),
    (w1_oc_ndcg, w3_oc_ndcg, w5_oc_ndcg, w7_oc_ndcg, w10_oc_ndcg),
]

labels = ["w1 cc", "w1 cdcg", "w1 hr", "w1 ndcg"]
line_labels = ["w1", "w3", "w5", "w7", "w10"]

# Set Seaborn style
sns.set_style("whitegrid")

fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()

for i, (ax, y_values) in enumerate(zip(axes, data_pairs)):
    cmap = sns.color_palette("Blues", as_cmap=True)
    colors = [cmap(x) for x in np.linspace(0.5, 1.2, len(y_values))]  

    for j, (y, color) in enumerate(zip(y_values, colors)):
        sns.lineplot(x=x, y=y, ax=ax, label=line_labels[j], color=color)

    ax.set_xlabel("X-axis Label")
    ax.set_ylabel(labels[i])
    ax.set_title(f"Plot {i+1}")
    ax.legend(loc="upper left")

plt.tight_layout()
plt.show()
#occupation

# %%
# for vaecf
w1_gen_gp = [0.051574973119749255,
 0.04386276492992912,
 0.0370959579392415,
 0.04525984546133805,
 0.06648759863685234,
 0.0841341096714231,
 0.09587698868295891,
 0.10447300129389682,
 0.12515155905454411]
w1_gen_gn = [0.021383100459483634,
 0.018544627458643798,
 0.017740883613675054,
 0.018926947806053217,
 0.024186553317599755,
 0.027364158708159995,
 0.03296153749066844,
 0.03914795252887792,
 0.043756075045767145]
w1_gen_hr =  [0.5387062566277837,
 0.5397667020148462,
 0.5418875927889714,
 0.5418875927889714,
 0.5387062566277837,
 0.545068928950159,
 0.5471898197242842,
 0.5482502651113468,
 0.528101802757158]
w1_gen_ndcg = [0.06877010356676778,
 0.06845512981507083,
 0.0681733097790699,
 0.06825044765716551,
 0.06795910415132123,
 0.0702580595095167,
 0.06819120216262173,
 0.06513501858238155,
 0.05627188688917504]

w3_gend_gn = [0.021383100459483634,
 0.018493260792951882,
 0.017139540653220098,
 0.01840340862673237,
 0.023216309178133922,
 0.025839085430566736,
 0.03166111573806769,
 0.03962095196279155,
 0.03719940545452778]
w3_gend_gp = [0.051574973119749255,
 0.044242195615329924,
 0.03556545113261538,
 0.04296290525395007,
 0.06294565633371606,
 0.0779997722012648,
 0.09172385326116667,
 0.10900505713192282,
 0.10136177172744336]
w3_gend_hr = [0.5387062566277837,
 0.5418875927889714,
 0.542948038176034,
 0.5387062566277837,
 0.5440084835630965,
 0.5461293743372216,
 0.5365853658536586,
 0.5164369034994698,
 0.5079533404029692]
w3_gend_ndcg = [0.06877010356676778,
 0.06838473458190673,
 0.06849767512379933,
 0.06831636987374444,
 0.06831058530384918,
 0.07011266066164484,
 0.06801838294649933,
 0.06156973914607532,
 0.05282011258084795]

w5_gen_gp = [0.051574973119749255,
 0.04426576822845481,
 0.03528293514114408,
 0.043939432872268695,
 0.05814600987735315,
 0.0758527691214258,
 0.09716366883531061,
 0.08638025076084781,
 0.10336194485448216]
w5_gen_gn = [0.021383100459483634,
 0.01847497230212163,
 0.016879631355562873,
 0.017956113275915044,
 0.02208699119753519,
 0.025484458733070578,
 0.03249891118614012,
 0.03383646268323461,
 0.03856045920224307]
w5_gen_hr = [0.5387062566277837,
 0.542948038176034,
 0.542948038176034,
 0.5418875927889714,
 0.542948038176034,
 0.5440084835630965,
 0.5365853658536586,
 0.5174973488865323,
 0.5185577942735949]
w5_gen_ndcg = [0.06877010356676778,
 0.06832199206475419,
 0.06844056559616646,
 0.06816501466462825,
 0.06883197801999597,
 0.06957243794259345,
 0.06820774039917808,
 0.06063762326145062,
 0.05449763582574621]

w7_gen_ndcg = [0.06877010356676778,
 0.06824583467782104,
 0.0681622962509984,
 0.06831965602868778,
 0.06881009147544505,
 0.06929381165006314,
 0.06737115687889242,
 0.059890928120103895,
 0.05170691847665989]
w7_gen_hr = [0.5387062566277837,
 0.5440084835630965,
 0.5397667020148462,
 0.5397667020148462,
 0.5503711558854719,
 0.542948038176034,
 0.5249204665959704,
 0.5121951219512195,
 0.4899257688229056]
w7_gen_gp = [0.051574973119749255,
 0.04545228983288684,
 0.0344221110564394,
 0.03936491534998997,
 0.052201620104605204,
 0.07611846445428533,
 0.07636844167441177,
 0.07483904652561367,
 0.10121452262497033]
w7_gen_gn = [0.021383100459483634,
 0.01873736124726332,
 0.01627314930119326,
 0.016599876217310072,
 0.02060973348280548,
 0.024400363193871615,
 0.02802461398092602,
 0.02971965473738473,
 0.03643424672165553]

w10_gen_gn = [0.021383100459483634,
 0.019060248126558852,
 0.016066701683296544,
 0.016068720293675176,
 0.01802384367682853,
 0.02449821170893075,
 0.02595946642769395,
 0.026713625013132108,
 0.02932342038938593]
w10_gen_gp = [0.051574973119749255,
 0.046390146337907494,
 0.037231826216900826,
 0.03630871284602626,
 0.04761822754360067,
 0.08152139485721574,
 0.07189075683851802,
 0.06737789076595041,
 0.10209779855302238]
w10_gen_hr =[0.5387062566277837,
 0.5461293743372216,
 0.545068928950159,
 0.542948038176034,
 0.5567338282078473,
 0.5365853658536586,
 0.5418875927889714,
 0.5143160127253447,
 0.4973488865323436]
w10_gen_ndcg = [0.06877010356676778,
 0.06841963398063582,
 0.06821400310713603,
 0.06855464922405174,
 0.06943155319222806,
 0.06891437605489319,
 0.06688509379433805,
 0.058212572642148575,
 0.05356325212495113]

# %%
x = list(range(0,9))
data_pairs = [
    (w1_gen_gp, w3_gend_gp, w5_gen_gp, w7_gen_gp, w10_gen_gp),
    (w1_gen_gn, w3_gend_gn, w5_gen_gn, w7_gen_gn, w10_gen_gn),
    (w1_gen_hr, w3_gend_hr, w5_gen_hr, w7_gen_hr, w10_gen_hr),
    (w1_gen_ndcg, w3_gend_ndcg, w5_gen_ndcg, w7_gen_ndcg, w10_gen_ndcg),
]
labels =  ["w1", "w1", "w1", "w1"]
labels2 =  ["w3", "w3", "w3", "w3"]
labels3 =  ["w5", "w5", "w5", "w5"]
labels4 =  ["w7", "w7", "w7", "w7"]
labels5 =  ["w10", "w10", "w10", "w10"]
plotTitles = ["CC bias 1","CDCG bias 2","HR performance 1","NDCG performance 2"]
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()
for i, (ax, (y_left, y_right, y_another, y_7, y_10)) in enumerate(zip(axes, data_pairs)):
    print(i)
    ax.plot(x, y_left, 'b-o', label=f"{labels[i]}")
    ax.tick_params(axis='y', labelcolor='b')

    ax.plot(x, y_right, 'r-s',label=f"{labels2[i]}")
    ax.tick_params(axis='y', labelcolor='r')
    
    ax.plot(x, y_another, 'g-s', label=f"{labels3[i]}")
    ax.tick_params(axis='y', labelcolor='g')
    
    ax.plot(x, y_7, 'c-s', label=f"{labels4[i]}")
    ax.tick_params(axis='y', labelcolor='c')
    ax.plot(x, y_10, 'm-s', label=f"{labels5[i]}")
    ax.tick_params(axis='y', labelcolor='m')

    ax.set_xlabel("X-axis Label")
    ax.set_title(f"{plotTitles[i]}")
    ax.legend(loc="upper left")
    

plt.tight_layout()
plt.show()
# Out:
# 0
# 1
# 2
# 3
